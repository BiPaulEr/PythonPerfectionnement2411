# %%
def function(a, b, *args):
    print(a, b, args)
function(2, 5, 6)
# Out:
# 2 5 (6,)

# %%
args = (4, 5)
#function((4, 5)) -> function(4, 5)
function(4, 5)
# Out:
# 4 5 ()

# %%
def function(a = 5, b = 6, c = 8, **kwargs):
    print(a, b, c, kwargs)
function(c = 12, d = 35)
# Out:
# 5 6 12 {'d': 35}
